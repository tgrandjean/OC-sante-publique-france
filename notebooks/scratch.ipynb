# %%
import pandas as pd
import csv
from pprint import pprint

# %%
data = pd.read_csv('../data/raw/products.csv', delimiter='\t', low_memory=False)

# %%
data.head()
# Out:
#                    code                                                url  \
# 0         0000000000017  http://world-en.openfoodfacts.org/product/0000...
# 1         0000000000031  http://world-en.openfoodfacts.org/product/0000...
# 2         0000000000100  http://world-en.openfoodfacts.org/product/0000...
# 3  00000000001111111111  http://world-en.openfoodfacts.org/product/0000...
# 4         0000000000123  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0                     kiliweb  1529059080  2018-06-15T10:38:00Z
# 1                    isagoofy  1539464774  2018-10-13T21:06:14Z
# 2                       del51  1444572561  2015-10-11T14:09:21Z
# 3  openfoodfacts-contributors  1560020173  2019-06-08T18:56:13Z
# 4                     kiliweb  1535737982  2018-08-31T17:53:02Z
#
#    last_modified_t last_modified_datetime                  product_name  \
# ...

# %%
data.describe()
# Out:
#           created_t  last_modified_t  cities  allergens_en  serving_quantity  \
# count  1.043719e+06     1.043719e+06     0.0           0.0      2.799250e+05
# mean   1.519987e+09     1.542354e+09     NaN           NaN      3.969317e+16
# std    4.128915e+07     3.097507e+07     NaN           NaN      2.100084e+19
# min    0.000000e+00     1.333873e+09     NaN           NaN      0.000000e+00
# 25%    1.489095e+09     1.528727e+09     NaN           NaN      2.800000e+01
# 50%    1.526059e+09     1.553782e+09     NaN           NaN      5.000000e+01
# 75%    1.552984e+09     1.564430e+09     NaN           NaN      1.130000e+02
# max    1.573781e+09     1.573781e+09     NaN           NaN      1.111111e+22
#
#        no_nutriments    additives_n  ingredients_from_palm_oil_n  \
# count            0.0  450296.000000                450296.000000
# mean             NaN       1.622115                     0.027193
# std              NaN       2.349639                     0.164587
# ...

# %%
len(data['creator'].drop_duplicates())
# Out:
# 9611
